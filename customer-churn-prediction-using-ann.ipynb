# %%
# necessary imports 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\sahithi\Downloads\Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# checking for null values

df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
values = df.Exited.value_counts()
labels = ['Not Exited', 'Exited']

fig, ax = plt.subplots(figsize = (4, 3), dpi = 100)
explode = (0, 0.09)

patches, texts, autotexts = ax.pie(values, labels = labels, autopct = '%1.2f%%', shadow = True,
                                   startangle = 90, explode = explode)

plt.setp(texts, color = 'grey')
plt.setp(autotexts, size = 8, color = 'white')
autotexts[1].set_color('black')
plt.show()

# %%
# visualizing categorical variables

fig, ax = plt.subplots(3, 2, figsize = (18, 15))

sns.countplot('Geography', hue = 'Exited', data = df, ax = ax[0][0])
sns.countplot('Gender', hue = 'Exited', data = df, ax = ax[0][1])
sns.countplot('Tenure', hue = 'Exited', data = df, ax = ax[1][0])
sns.countplot('NumOfProducts', hue = 'Exited', data = df, ax = ax[1][1])
sns.countplot('HasCrCard', hue = 'Exited', data = df, ax = ax[2][0])
sns.countplot('IsActiveMember', hue = 'Exited', data = df, ax = ax[2][1])

plt.tight_layout()
plt.show()

# %%
# visualizing continuous variables

fig, ax = plt.subplots(2, 2, figsize = (16, 10))

sns.boxplot(x = 'Exited', y = 'CreditScore', data = df, ax = ax[0][0])
sns.boxplot(x = 'Exited', y = 'Age', data = df, ax = ax[0][1])
sns.boxplot(x = 'Exited', y = 'Balance', data = df, ax = ax[1][0])
sns.boxplot(x = 'Exited', y = 'EstimatedSalary', data = df, ax = ax[1][1])

plt.tight_layout()
plt.show()

# %%
# heatmap 

plt.figure(figsize = (20, 12))

corr = df.corr()

sns.heatmap(corr, linewidths = 1, annot = True, fmt = ".2f")
plt.show()

# %%
# dropping useless columns 

df.drop(columns = ['RowNumber', 'CustomerId', 'Surname'], axis = 1, inplace = True)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df.Geography.value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
# Encoding categorical variables

df['Geography'] = df['Geography'].map({'France' : 0, 'Germany' : 1, 'Spain' : 2})
df['Gender'] = df['Gender'].map({'Male' : 0, 'Female' : 1})

# %%
df.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       1   42       2       0.00              1
# 1          608          2       1   41       1   83807.86              1
# 2          502          0       1   42       8  159660.80              3
# 3          699          0       1   39       1       0.00              2
# 4          850          2       1   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# creating features and label 

from tensorflow.keras.utils import to_categorical

X = df.drop('Exited', axis = 1)
y = to_categorical(df.Exited)

# %%
# splitting data into training set and test set

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
# Scaling data

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import BatchNormalization

# initializing ann
model = Sequential()

# adding the first input layer and the first hidden layer
model.add(Dense(10, kernel_initializer = 'normal', activation = 'relu', input_shape = (10, )))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the third hidden layer
model.add(Dense(7, kernel_initializer = 'normal', activation = 'relu'))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the output layer
model.add(Dense(2, kernel_initializer = 'normal', activation = 'sigmoid'))

# compiling the model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# fitting the model to the training set 

model_history = model.fit(X_train, y_train, validation_split = 0.20, validation_data = (X_test, y_test), epochs = 100)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 6s 9ms/step - loss: 0.6056 - accuracy: 0.6881 - val_loss: 0.5437 - val_accuracy: 0.7932
# Epoch 2/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4433 - accuracy: 0.8216 - val_loss: 0.4168 - val_accuracy: 0.8240
# Epoch 3/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3891 - accuracy: 0.8413 - val_loss: 0.3785 - val_accuracy: 0.8492
# Epoch 4/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3824 - accuracy: 0.8444 - val_loss: 0.3704 - val_accuracy: 0.8504
# Epoch 5/100
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3790 - accuracy: 0.8391 - val_loss: 0.3689 - val_accuracy: 0.8448
# Epoch 6/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3742 - accuracy: 0.8452 - val_loss: 0.3676 - val_accuracy: 0.8472
# Epoch 7/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3739 - accuracy: 0.8451 - val_loss: 0.3720 - val_accuracy: 0.8472
# Epoch 8/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3737 - accuracy: 0.8443 - val_loss: 0.3705 - val_accuracy: 0.8456
# Epoch 9/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3684 - accuracy: 0.8448 - val_loss: 0.3668 - val_accuracy: 0.8488
# Epoch 10/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3699 - accuracy: 0.8455 - val_loss: 0.3669 - val_accuracy: 0.8472
# Epoch 11/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3689 - accuracy: 0.8437 - val_loss: 0.3674 - val_accuracy: 0.8476
# Epoch 12/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3671 - accuracy: 0.8437 - val_loss: 0.3645 - val_accuracy: 0.8512
# Epoch 13/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3679 - accuracy: 0.8445 - val_loss: 0.3659 - val_accuracy: 0.8520
# Epoch 14/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3693 - accuracy: 0.8503 - val_loss: 0.3669 - val_accuracy: 0.8496
# Epoch 15/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3660 - accuracy: 0.8467 - val_loss: 0.3715 - val_accuracy: 0.8508
# Epoch 16/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3669 - accuracy: 0.8475 - val_loss: 0.3700 - val_accuracy: 0.8460
# Epoch 17/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3648 - accuracy: 0.8468 - val_loss: 0.3657 - val_accuracy: 0.8488
# Epoch 18/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3612 - accuracy: 0.8471 - val_loss: 0.3644 - val_accuracy: 0.8496
# Epoch 19/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3698 - accuracy: 0.8433 - val_loss: 0.3701 - val_accuracy: 0.8472
# Epoch 20/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3669 - accuracy: 0.8484 - val_loss: 0.3645 - val_accuracy: 0.8516
# Epoch 21/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3628 - accuracy: 0.8469 - val_loss: 0.3670 - val_accuracy: 0.8504
# Epoch 22/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3640 - accuracy: 0.8513 - val_loss: 0.3706 - val_accuracy: 0.8512
# Epoch 23/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3608 - accuracy: 0.8492 - val_loss: 0.3663 - val_accuracy: 0.8524
# Epoch 24/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3597 - accuracy: 0.8495 - val_loss: 0.3644 - val_accuracy: 0.8512
# Epoch 25/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3642 - accuracy: 0.8480 - val_loss: 0.3635 - val_accuracy: 0.8516
# Epoch 26/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3645 - accuracy: 0.8472 - val_loss: 0.3643 - val_accuracy: 0.8516
# Epoch 27/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3628 - accuracy: 0.8464 - val_loss: 0.3624 - val_accuracy: 0.8560
# Epoch 28/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3621 - accuracy: 0.8459 - val_loss: 0.3624 - val_accuracy: 0.8536
# Epoch 29/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3625 - accuracy: 0.8525 - val_loss: 0.3599 - val_accuracy: 0.8540
# Epoch 30/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3616 - accuracy: 0.8461 - val_loss: 0.3602 - val_accuracy: 0.8536
# Epoch 31/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3632 - accuracy: 0.8479 - val_loss: 0.3619 - val_accuracy: 0.8544
# Epoch 32/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3577 - accuracy: 0.8487 - val_loss: 0.3616 - val_accuracy: 0.8536
# Epoch 33/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3598 - accuracy: 0.8488 - val_loss: 0.3605 - val_accuracy: 0.8528
# Epoch 34/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3572 - accuracy: 0.8487 - val_loss: 0.3596 - val_accuracy: 0.8528
# Epoch 35/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3582 - accuracy: 0.8484 - val_loss: 0.3619 - val_accuracy: 0.8524
# Epoch 36/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3653 - accuracy: 0.8437 - val_loss: 0.3654 - val_accuracy: 0.8472
# Epoch 37/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3599 - accuracy: 0.8507 - val_loss: 0.3621 - val_accuracy: 0.8536
# Epoch 38/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3664 - accuracy: 0.8472 - val_loss: 0.3615 - val_accuracy: 0.8492
# Epoch 39/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3625 - accuracy: 0.8439 - val_loss: 0.3680 - val_accuracy: 0.8468
# Epoch 40/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3582 - accuracy: 0.8492 - val_loss: 0.3595 - val_accuracy: 0.8536
# Epoch 41/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3584 - accuracy: 0.8520 - val_loss: 0.3630 - val_accuracy: 0.8508
# Epoch 42/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3577 - accuracy: 0.8515 - val_loss: 0.3624 - val_accuracy: 0.8492
# Epoch 43/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3628 - accuracy: 0.8476 - val_loss: 0.3631 - val_accuracy: 0.8520
# Epoch 44/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3658 - accuracy: 0.8484 - val_loss: 0.3603 - val_accuracy: 0.8540
# Epoch 45/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3623 - accuracy: 0.8451 - val_loss: 0.3656 - val_accuracy: 0.8564
# Epoch 46/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3631 - accuracy: 0.8477 - val_loss: 0.3657 - val_accuracy: 0.8468
# Epoch 47/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3620 - accuracy: 0.8443 - val_loss: 0.3634 - val_accuracy: 0.8540
# Epoch 48/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3593 - accuracy: 0.8511 - val_loss: 0.3625 - val_accuracy: 0.8532
# Epoch 49/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3583 - accuracy: 0.8524 - val_loss: 0.3614 - val_accuracy: 0.8540
# Epoch 50/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3641 - accuracy: 0.8492 - val_loss: 0.3649 - val_accuracy: 0.8504
# Epoch 51/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3594 - accuracy: 0.8503 - val_loss: 0.3634 - val_accuracy: 0.8488
# Epoch 52/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3603 - accuracy: 0.8475 - val_loss: 0.3670 - val_accuracy: 0.8504
# Epoch 53/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3588 - accuracy: 0.8479 - val_loss: 0.3663 - val_accuracy: 0.8480
# Epoch 54/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3638 - accuracy: 0.8483 - val_loss: 0.3655 - val_accuracy: 0.8504
# Epoch 55/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3588 - accuracy: 0.8479 - val_loss: 0.3647 - val_accuracy: 0.8456
# Epoch 56/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3589 - accuracy: 0.8493 - val_loss: 0.3640 - val_accuracy: 0.8528
# Epoch 57/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3586 - accuracy: 0.8507 - val_loss: 0.3636 - val_accuracy: 0.8516
# Epoch 58/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3583 - accuracy: 0.8516 - val_loss: 0.3619 - val_accuracy: 0.8496
# Epoch 59/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3633 - accuracy: 0.8491 - val_loss: 0.3606 - val_accuracy: 0.8548
# Epoch 60/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3593 - accuracy: 0.8436 - val_loss: 0.3615 - val_accuracy: 0.8556
# Epoch 61/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3602 - accuracy: 0.8504 - val_loss: 0.3621 - val_accuracy: 0.8528
# Epoch 62/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3630 - accuracy: 0.8468 - val_loss: 0.3626 - val_accuracy: 0.8544
# Epoch 63/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3605 - accuracy: 0.8499 - val_loss: 0.3616 - val_accuracy: 0.8516
# Epoch 64/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3626 - accuracy: 0.8481 - val_loss: 0.3622 - val_accuracy: 0.8552
# Epoch 65/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3571 - accuracy: 0.8508 - val_loss: 0.3596 - val_accuracy: 0.8544
# Epoch 66/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3575 - accuracy: 0.8509 - val_loss: 0.3606 - val_accuracy: 0.8564
# Epoch 67/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3589 - accuracy: 0.8527 - val_loss: 0.3608 - val_accuracy: 0.8544
# Epoch 68/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3536 - accuracy: 0.8512 - val_loss: 0.3600 - val_accuracy: 0.8532
# Epoch 69/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3607 - accuracy: 0.8507 - val_loss: 0.3621 - val_accuracy: 0.8512
# Epoch 70/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3572 - accuracy: 0.8532 - val_loss: 0.3616 - val_accuracy: 0.8520
# Epoch 71/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3585 - accuracy: 0.8548 - val_loss: 0.3613 - val_accuracy: 0.8508
# Epoch 72/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3569 - accuracy: 0.8515 - val_loss: 0.3619 - val_accuracy: 0.8520
# Epoch 73/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3628 - accuracy: 0.8500 - val_loss: 0.3623 - val_accuracy: 0.8544
# Epoch 74/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3592 - accuracy: 0.8521 - val_loss: 0.3608 - val_accuracy: 0.8504
# Epoch 75/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3594 - accuracy: 0.8528 - val_loss: 0.3626 - val_accuracy: 0.8500
# Epoch 76/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3614 - accuracy: 0.8515 - val_loss: 0.3641 - val_accuracy: 0.8508
# Epoch 77/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3587 - accuracy: 0.8485 - val_loss: 0.3610 - val_accuracy: 0.8512
# Epoch 78/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3583 - accuracy: 0.8488 - val_loss: 0.3604 - val_accuracy: 0.8500
# Epoch 79/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3581 - accuracy: 0.8504 - val_loss: 0.3596 - val_accuracy: 0.8540
# Epoch 80/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3536 - accuracy: 0.8547 - val_loss: 0.3586 - val_accuracy: 0.8536
# Epoch 81/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3618 - accuracy: 0.8515 - val_loss: 0.3597 - val_accuracy: 0.8524
# Epoch 82/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3526 - accuracy: 0.8527 - val_loss: 0.3598 - val_accuracy: 0.8540
# Epoch 83/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.3546 - accuracy: 0.8508 - val_loss: 0.3606 - val_accuracy: 0.8500
# Epoch 84/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3551 - accuracy: 0.8560 - val_loss: 0.3593 - val_accuracy: 0.8532
# Epoch 85/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3571 - accuracy: 0.8544 - val_loss: 0.3628 - val_accuracy: 0.8500
# Epoch 86/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3553 - accuracy: 0.8529 - val_loss: 0.3592 - val_accuracy: 0.8528
# Epoch 87/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3576 - accuracy: 0.8531 - val_loss: 0.3609 - val_accuracy: 0.8504
# Epoch 88/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3599 - accuracy: 0.8489 - val_loss: 0.3607 - val_accuracy: 0.8516
# Epoch 89/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3601 - accuracy: 0.8513 - val_loss: 0.3586 - val_accuracy: 0.8532
# Epoch 90/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3575 - accuracy: 0.8504 - val_loss: 0.3619 - val_accuracy: 0.8488
# Epoch 91/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3541 - accuracy: 0.8524 - val_loss: 0.3665 - val_accuracy: 0.8500
# Epoch 92/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3612 - accuracy: 0.8509 - val_loss: 0.3576 - val_accuracy: 0.8524
# Epoch 93/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3593 - accuracy: 0.8480 - val_loss: 0.3581 - val_accuracy: 0.8544
# Epoch 94/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3577 - accuracy: 0.8527 - val_loss: 0.3605 - val_accuracy: 0.8540
# Epoch 95/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3608 - accuracy: 0.8501 - val_loss: 0.3672 - val_accuracy: 0.8492
# Epoch 96/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3588 - accuracy: 0.8509 - val_loss: 0.3584 - val_accuracy: 0.8552
# Epoch 97/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3599 - accuracy: 0.8545 - val_loss: 0.3614 - val_accuracy: 0.8544
# Epoch 98/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3584 - accuracy: 0.8488 - val_loss: 0.3608 - val_accuracy: 0.8504
# Epoch 99/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3567 - accuracy: 0.8489 - val_loss: 0.3591 - val_accuracy: 0.8532
# Epoch 100/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3568 - accuracy: 0.8501 - val_loss: 0.3610 - val_accuracy: 0.8504

# %%
plt.figure(figsize = (12, 6))

train_loss = model_history.history['loss']
val_loss = model_history.history['val_loss'] 
epoch = range(1, 101)
sns.lineplot(epoch, train_loss, label = 'Training Loss')
sns.lineplot(epoch, val_loss, label = 'Validation Loss')
plt.title('Training and Validation Loss\n')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 6))

train_loss = model_history.history['accuracy']
val_loss = model_history.history['val_accuracy'] 
epoch = range(1, 101)
sns.lineplot(epoch, train_loss, label = 'Training accuracy')
sns.lineplot(epoch, val_loss, label = 'Validation accuracy')
plt.title('Training and Validation Accuracy\n')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
acc = model.evaluate(X_test, y_test)[1]

print(f'Accuracy of model is {acc}')
# Out:
# 79/79 [==============================] - 0s 2ms/step - loss: 0.3610 - accuracy: 0.8504
# Accuracy of model is 0.8503999710083008

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                110
#
#  dropout (Dropout)           (None, 10)                0
#
#  batch_normalization (BatchN  (None, 10)               40
#  ormalization)
#
#  dense_1 (Dense)             (None, 7)                 77
#
#  dropout_1 (Dropout)         (None, 7)                 0
#
#  batch_normalization_1 (Batc  (None, 7)                28
#  hNormalization)
#
#  dense_2 (Dense)             (None, 2)                 16
#
# =================================================================
# Total params: 271
# Trainable params: 237
# Non-trainable params: 34
# _________________________________________________________________

# %%
model = Sequential()

# adding the first input layer and the first hidden layer
model.add(Dense(10, kernel_initializer = 'normal', activation = 'relu', input_shape = (10, )))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.6))
model.add(BatchNormalization())

# adding the third hidden layer
model.add(Dense(7, kernel_initializer = 'normal', activation = 'relu'))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.6))
model.add(BatchNormalization())

# adding the output layer
model.add(Dense(2, kernel_initializer = 'normal', activation = 'sigmoid'))

# compiling the model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# fitting the model to the training set 

model_history = model.fit(X_train, y_train, validation_split = 0.20, validation_data = (X_test, y_test), epochs = 100)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 4s 6ms/step - loss: 0.6418 - accuracy: 0.7415 - val_loss: 0.5743 - val_accuracy: 0.7932
# Epoch 2/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5132 - accuracy: 0.7865 - val_loss: 0.4730 - val_accuracy: 0.7924
# Epoch 3/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4764 - accuracy: 0.7952 - val_loss: 0.4629 - val_accuracy: 0.7940
# Epoch 4/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4713 - accuracy: 0.7935 - val_loss: 0.4558 - val_accuracy: 0.7928
# Epoch 5/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4570 - accuracy: 0.7999 - val_loss: 0.4476 - val_accuracy: 0.7976
# Epoch 6/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4652 - accuracy: 0.7955 - val_loss: 0.4454 - val_accuracy: 0.8020
# Epoch 7/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4675 - accuracy: 0.7953 - val_loss: 0.4427 - val_accuracy: 0.7996
# Epoch 8/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4577 - accuracy: 0.7987 - val_loss: 0.4376 - val_accuracy: 0.8036
# Epoch 9/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4632 - accuracy: 0.7995 - val_loss: 0.4386 - val_accuracy: 0.8044
# Epoch 10/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4541 - accuracy: 0.8036 - val_loss: 0.4364 - val_accuracy: 0.8036
# Epoch 11/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4519 - accuracy: 0.8041 - val_loss: 0.4279 - val_accuracy: 0.8160
# Epoch 12/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4584 - accuracy: 0.7999 - val_loss: 0.4297 - val_accuracy: 0.8120
# Epoch 13/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4553 - accuracy: 0.8039 - val_loss: 0.4223 - val_accuracy: 0.8184
# Epoch 14/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4564 - accuracy: 0.8061 - val_loss: 0.4231 - val_accuracy: 0.8160
# Epoch 15/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4516 - accuracy: 0.8093 - val_loss: 0.4205 - val_accuracy: 0.8236
# Epoch 16/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4565 - accuracy: 0.8065 - val_loss: 0.4175 - val_accuracy: 0.8208
# Epoch 17/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4552 - accuracy: 0.8057 - val_loss: 0.4188 - val_accuracy: 0.8220
# Epoch 18/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4499 - accuracy: 0.8097 - val_loss: 0.4094 - val_accuracy: 0.8316
# Epoch 19/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4446 - accuracy: 0.8112 - val_loss: 0.4091 - val_accuracy: 0.8308
# Epoch 20/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4429 - accuracy: 0.8100 - val_loss: 0.4060 - val_accuracy: 0.8336
# Epoch 21/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4451 - accuracy: 0.8121 - val_loss: 0.3984 - val_accuracy: 0.8380
# Epoch 22/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4408 - accuracy: 0.8147 - val_loss: 0.3969 - val_accuracy: 0.8364
# Epoch 23/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4374 - accuracy: 0.8167 - val_loss: 0.3939 - val_accuracy: 0.8404
# Epoch 24/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4471 - accuracy: 0.8139 - val_loss: 0.4012 - val_accuracy: 0.8340
# Epoch 25/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4461 - accuracy: 0.8156 - val_loss: 0.3907 - val_accuracy: 0.8428
# Epoch 26/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4474 - accuracy: 0.8157 - val_loss: 0.3996 - val_accuracy: 0.8352
# Epoch 27/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4427 - accuracy: 0.8184 - val_loss: 0.4080 - val_accuracy: 0.8252
# Epoch 28/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4501 - accuracy: 0.8165 - val_loss: 0.4086 - val_accuracy: 0.8300
# Epoch 29/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4511 - accuracy: 0.8171 - val_loss: 0.4070 - val_accuracy: 0.8276
# Epoch 30/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4466 - accuracy: 0.8175 - val_loss: 0.4099 - val_accuracy: 0.8284
# Epoch 31/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4489 - accuracy: 0.8143 - val_loss: 0.4031 - val_accuracy: 0.8328
# Epoch 32/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4486 - accuracy: 0.8135 - val_loss: 0.3967 - val_accuracy: 0.8380
# Epoch 33/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4419 - accuracy: 0.8204 - val_loss: 0.4086 - val_accuracy: 0.8272
# Epoch 34/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4485 - accuracy: 0.8153 - val_loss: 0.3966 - val_accuracy: 0.8372
# Epoch 35/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4423 - accuracy: 0.8185 - val_loss: 0.4010 - val_accuracy: 0.8332
# Epoch 36/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4439 - accuracy: 0.8179 - val_loss: 0.4007 - val_accuracy: 0.8336
# Epoch 37/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4442 - accuracy: 0.8155 - val_loss: 0.4055 - val_accuracy: 0.8288
# Epoch 38/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4420 - accuracy: 0.8157 - val_loss: 0.3935 - val_accuracy: 0.8392
# Epoch 39/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4414 - accuracy: 0.8156 - val_loss: 0.3981 - val_accuracy: 0.8336
# Epoch 40/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4421 - accuracy: 0.8193 - val_loss: 0.3961 - val_accuracy: 0.8368
# Epoch 41/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4430 - accuracy: 0.8192 - val_loss: 0.4009 - val_accuracy: 0.8332
# Epoch 42/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4462 - accuracy: 0.8188 - val_loss: 0.3974 - val_accuracy: 0.8396
# Epoch 43/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4444 - accuracy: 0.8161 - val_loss: 0.4035 - val_accuracy: 0.8300
# Epoch 44/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4405 - accuracy: 0.8196 - val_loss: 0.3941 - val_accuracy: 0.8400
# Epoch 45/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4420 - accuracy: 0.8163 - val_loss: 0.3963 - val_accuracy: 0.8388
# Epoch 46/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4429 - accuracy: 0.8179 - val_loss: 0.4070 - val_accuracy: 0.8232
# Epoch 47/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4422 - accuracy: 0.8184 - val_loss: 0.4004 - val_accuracy: 0.8324
# Epoch 48/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4422 - accuracy: 0.8176 - val_loss: 0.3995 - val_accuracy: 0.8340
# Epoch 49/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4406 - accuracy: 0.8207 - val_loss: 0.3915 - val_accuracy: 0.8408
# Epoch 50/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4425 - accuracy: 0.8160 - val_loss: 0.4020 - val_accuracy: 0.8276
# Epoch 51/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4424 - accuracy: 0.8185 - val_loss: 0.4040 - val_accuracy: 0.8292
# Epoch 52/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4407 - accuracy: 0.8193 - val_loss: 0.3961 - val_accuracy: 0.8404
# Epoch 53/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4462 - accuracy: 0.8148 - val_loss: 0.4045 - val_accuracy: 0.8248
# Epoch 54/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4468 - accuracy: 0.8136 - val_loss: 0.3996 - val_accuracy: 0.8316
# Epoch 55/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4446 - accuracy: 0.8169 - val_loss: 0.4015 - val_accuracy: 0.8280
# Epoch 56/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4390 - accuracy: 0.8201 - val_loss: 0.4010 - val_accuracy: 0.8300
# Epoch 57/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4439 - accuracy: 0.8213 - val_loss: 0.4051 - val_accuracy: 0.8268
# Epoch 58/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4410 - accuracy: 0.8207 - val_loss: 0.4029 - val_accuracy: 0.8284
# Epoch 59/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.4451 - accuracy: 0.8173 - val_loss: 0.4211 - val_accuracy: 0.8132
# Epoch 60/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4439 - accuracy: 0.8181 - val_loss: 0.4020 - val_accuracy: 0.8300
# Epoch 61/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4505 - accuracy: 0.8191 - val_loss: 0.4011 - val_accuracy: 0.8352
# Epoch 62/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.4477 - accuracy: 0.8153 - val_loss: 0.4021 - val_accuracy: 0.8332
# Epoch 63/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4443 - accuracy: 0.8173 - val_loss: 0.3978 - val_accuracy: 0.8356
# Epoch 64/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4400 - accuracy: 0.8181 - val_loss: 0.3960 - val_accuracy: 0.8360
# Epoch 65/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4407 - accuracy: 0.8181 - val_loss: 0.4000 - val_accuracy: 0.8320
# Epoch 66/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.4428 - accuracy: 0.8192 - val_loss: 0.4020 - val_accuracy: 0.8328
# Epoch 67/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4424 - accuracy: 0.8184 - val_loss: 0.3944 - val_accuracy: 0.8372
# Epoch 68/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.4417 - accuracy: 0.8199 - val_loss: 0.4000 - val_accuracy: 0.8308
# Epoch 69/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4437 - accuracy: 0.8223 - val_loss: 0.3933 - val_accuracy: 0.8380
# Epoch 70/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4435 - accuracy: 0.8183 - val_loss: 0.3936 - val_accuracy: 0.8392
# Epoch 71/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.4426 - accuracy: 0.8197 - val_loss: 0.3958 - val_accuracy: 0.8384
# Epoch 72/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4411 - accuracy: 0.8205 - val_loss: 0.4006 - val_accuracy: 0.8336
# Epoch 73/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.4446 - accuracy: 0.8160 - val_loss: 0.4015 - val_accuracy: 0.8320
# Epoch 74/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4355 - accuracy: 0.8239 - val_loss: 0.4014 - val_accuracy: 0.8312
# Epoch 75/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4454 - accuracy: 0.8168 - val_loss: 0.4000 - val_accuracy: 0.8336
# Epoch 76/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4423 - accuracy: 0.8196 - val_loss: 0.3946 - val_accuracy: 0.8364
# Epoch 77/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4395 - accuracy: 0.8149 - val_loss: 0.3986 - val_accuracy: 0.8332
# Epoch 78/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4410 - accuracy: 0.8173 - val_loss: 0.4023 - val_accuracy: 0.8284
# Epoch 79/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4428 - accuracy: 0.8161 - val_loss: 0.3968 - val_accuracy: 0.8320
# Epoch 80/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4411 - accuracy: 0.8176 - val_loss: 0.3956 - val_accuracy: 0.8380
# Epoch 81/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.4438 - accuracy: 0.8168 - val_loss: 0.4044 - val_accuracy: 0.8320
# Epoch 82/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4432 - accuracy: 0.8143 - val_loss: 0.4071 - val_accuracy: 0.8288
# Epoch 83/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4482 - accuracy: 0.8144 - val_loss: 0.3968 - val_accuracy: 0.8348
# Epoch 84/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4429 - accuracy: 0.8155 - val_loss: 0.3978 - val_accuracy: 0.8332
# Epoch 85/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.4396 - accuracy: 0.8208 - val_loss: 0.4003 - val_accuracy: 0.8316
# Epoch 86/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4459 - accuracy: 0.8133 - val_loss: 0.4041 - val_accuracy: 0.8292
# Epoch 87/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4437 - accuracy: 0.8179 - val_loss: 0.4020 - val_accuracy: 0.8340
# Epoch 88/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.4441 - accuracy: 0.8175 - val_loss: 0.4026 - val_accuracy: 0.8320
# Epoch 89/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.4377 - accuracy: 0.8201 - val_loss: 0.3993 - val_accuracy: 0.8324
# Epoch 90/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4436 - accuracy: 0.8143 - val_loss: 0.3971 - val_accuracy: 0.8328
# Epoch 91/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4422 - accuracy: 0.8196 - val_loss: 0.3995 - val_accuracy: 0.8308
# Epoch 92/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4422 - accuracy: 0.8179 - val_loss: 0.3950 - val_accuracy: 0.8384
# Epoch 93/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4440 - accuracy: 0.8168 - val_loss: 0.3966 - val_accuracy: 0.8424
# Epoch 94/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.4362 - accuracy: 0.8203 - val_loss: 0.3984 - val_accuracy: 0.8348
# Epoch 95/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4435 - accuracy: 0.8163 - val_loss: 0.3985 - val_accuracy: 0.8364
# Epoch 96/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4415 - accuracy: 0.8189 - val_loss: 0.3982 - val_accuracy: 0.8360
# Epoch 97/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.4428 - accuracy: 0.8173 - val_loss: 0.3942 - val_accuracy: 0.8380
# Epoch 98/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.4484 - accuracy: 0.8132 - val_loss: 0.4011 - val_accuracy: 0.8372
# Epoch 99/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.4404 - accuracy: 0.8188 - val_loss: 0.3975 - val_accuracy: 0.8348
# Epoch 100/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.4427 - accuracy: 0.8167 - val_loss: 0.3942 - val_accuracy: 0.8404

# %%
plt.figure(figsize = (12, 6))

train_loss = model_history.history['loss']
val_loss = model_history.history['val_loss'] 
epoch = range(1, 101)
sns.lineplot(epoch, train_loss, label = 'Training Loss')
sns.lineplot(epoch, val_loss, label = 'Validation Loss')
plt.title('Training and Validation Loss\n')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12, 6))

train_loss = model_history.history['accuracy']
val_loss = model_history.history['val_accuracy'] 
epoch = range(1, 101)
sns.lineplot(epoch, train_loss, label = 'Training accuracy')
sns.lineplot(epoch, val_loss, label = 'Validation accuracy')
plt.title('Training and Validation Accuracy\n')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
acc = model.evaluate(X_test, y_test)[1]

print(f'Accuracy of model is {acc}')
# Out:
# 79/79 [==============================] - 0s 3ms/step - loss: 0.3942 - accuracy: 0.8404
# Accuracy of model is 0.840399980545044
